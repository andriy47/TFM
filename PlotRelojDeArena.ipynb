# %%
# %run methods.ipynb
# Out:
# [nltk_data] Downloading package stopwords to /Users/and/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Republicanos Donald Trump
list_of_files =['../FicherosJSON//P2REPUBLICANS_10000.json']
#Un unico dataframe
df = join_all_files_in_one_df(list_of_files)
dataFrames = df[1]

# %%
#DataFrame y numero de tweets deseados 0 para todos los tweets
dataDem = clean_data_from_json(dataFrames[0], 0)

# %%
#Republicanos Donald Trump
list_of_files =['../FicherosJSON//P1TheDemocrats_10000.json']
#Un unico dataframe
df = join_all_files_in_one_df(list_of_files)
dataFramesR = df[1]

# %%
#DataFrame y numero de tweets deseados 0 para todos los tweets
dataRep = clean_data_from_json(dataFramesR[0], 0)

# %%
dataRepNeg = [-x for x in dataRep[6]]

# %%
plt.plot(dataDem[5],dataDem[6],'.b', dataRep[5], dataRepNeg,'.r')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.title('ALL')
plt.show()

# %%
z = np.zeros((101,101))

# %%
for sx, sy in zip(dataDem[5],dataDem[6]):
    x = int(sx*50+50)
    y = int(sy*50+50)
    z[x,y] +=1

# %%
print(z)
# Out:
# [[0.000e+00 2.252e+03 3.400e+01 3.000e+00 0.000e+00 1.000e+00 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 7.000e+00 2.000e+00 8.600e+01]
#  [0.000e+00 7.000e+00 1.000e+00 5.900e+01 0.000e+00 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 1.000e+00 0.000e+00 1.000e+00 0.000e+00 2.800e+01]
#  [0.000e+00 1.700e+01 5.500e+01 2.000e+01 1.000e+00 1.000e+00 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 1.000e+00
#   0.000e+00 0.000e+00 0.000e+00 2.500e+01 1.500e+02 2.000e+01 3.200e+01]
#  [0.000e+00 5.000e+00 1.700e+01 1.100e+01 3.000e+00 8.000e+00 1.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 3.000e+00 0.000e+00
#   0.000e+00 0.000e+00 2.900e+01 7.000e+00 2.000e+01 8.000e+00 2.400e+01]
#  [0.000e+00 5.000e+00 5.000e+00 2.100e+01 4.000e+00 4.000e+00 4.000e+00
#   0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 1.000e+00
#   0.000e+00 3.000e+00 7.000e+00 4.000e+00 1.800e+01 1.200e+01 5.000e+00]
#  [0.000e+00 9.200e+01 2.400e+01 8.000e+00 8.000e+00 1.600e+01 1.200e+01
#   1.000e+00 3.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 5.000e+00
#   5.000e+00 3.400e+01 1.800e+01 8.000e+00 1.000e+01 2.500e+01 6.600e+01]
#  [0.000e+00 5.000e+00 1.000e+00 2.200e+01 1.300e+01 5.500e+01 7.500e+01
#   1.300e+01 7.000e+00 2.000e+00 0.000e+00 0.000e+00 0.000e+00 1.600e+01
#   1.900e+01 3.000e+01 7.200e+01 2.600e+01 1.200e+01 7.000e+00 6.000e+00]
#  [0.000e+00 9.000e+00 1.000e+00 4.000e+00 2.100e+01 1.300e+01 7.700e+01
#   1.600e+01 1.200e+01 5.000e+00 3.000e+00 2.000e+00 3.100e+01 6.000e+00
#   4.600e+01 3.400e+01 2.400e+01 1.100e+01 1.300e+01 5.000e+00 4.000e+00]
#  [0.000e+00 0.000e+00 2.000e+00 2.800e+01 8.000e+00 2.100e+01 2.200e+01
#   2.200e+01 2.600e+01 4.500e+01 3.600e+01 3.100e+01 3.700e+01 4.000e+01
.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 5.000e+00 1.000e+00 8.000e+00 2.000e+00 1.000e+00]
#  [0.000e+00 2.200e+01 1.000e+00 0.000e+00 3.000e+00 4.000e+00 0.000e+00
#   2.000e+00 1.500e+01 0.000e+00 0.000e+00 0.000e+00 0.000e+00 8.000e+00
#   0.000e+00 0.000e+00 3.000e+01 1.500e+01 0.000e+00 3.000e+00 8.000e+00]]

# %%
gx, gy = np.meshgrid(np.arange(0, 201, 1),np.arange(0, 201, 1))
z[100,100]=0
plt.contourf(gx,gy,z.transpose())
plt.show()

# %%
for sx, sy in zip(dataRep[5],dataRepNeg):
    x = int(sx*100+100)
    y = int(sy*100+100)
    z[x,y] -=1

# %%
z = np.ones((21,21))*0.00001
for sx, sy in zip(dataDem[5],dataDem[6]):
    x = int(sx*10+10)
    y = int(sy*10+10)
    z[x,y] +=1
for sx, sy in zip(dataRep[5],dataRepNeg):
    x = int(sx*10+10)
    y = int(sy*10+10)
    z[x,y] +=1

# %%
z[10,10]=0.00001

# %%
gx, gy = np.meshgrid(np.arange(0, 21, 1),np.arange(0, 21, 1))
plt.contourf(gx,gy,np.real(np.log((z.transpose()))))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z[10,10]=0
z[0,0]=0
ax.plot_surface(gx,gy,z.transpose())

# %%
gx, gy = np.meshgrid(np.arange(0, 21, 1),np.arange(0, 21, 1))
plt.contourf(gx,gy,log(z.transpose())) 
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
z[10,10]=0
ax.plot_surface(gx,gy,z.transpose())

# %%
#for sx, sy in zip(dataRep[5],dataRep[6]):
    x = int(sx*10+10)
    y = int(sy*10+10)
    z[x,y] +=1

# %%
data = [
    go.Mesh3d(
        x = [0, 0, 1, 1, 0, 0, 1, 1],
        y = [0, 1, 1, 0, 0, 1, 1, 0],
        z = [0, 0, 0, 0, 1, 1, 1, 1],
        colorbar = go.ColorBar(
            title='z'
        ),
        colorscale = [[0, 'rgb(255, 0, 255)'],
                    [0.5, 'rgb(0, 255, 0)'], 
                      [1, 'rgb(0, 0, 255)']],
        intensity = [0, 0.142857142857143, 0.285714285714286, 
                     0.428571428571429, 0.571428571428571, 
                     0.714285714285714, 0.857142857142857, 1],
        i = [7, 0, 0, 0, 4, 4, 6, 6, 4, 0, 3, 2],
        j = [3, 4, 1, 2, 5, 6, 5, 2, 0, 1, 6, 3],
        k = [0, 7, 2, 3, 6, 7, 1, 1, 5, 5, 7, 6],
        name='y',
        showscale=True
    )
]
layout = go.Layout(
    xaxis=go.XAxis(
        title='x'
    ),
    yaxis=go.YAxis(
        title='y'
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-mesh-cube-python')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-96403d6e63b0> in <module>
#       2
#       3 data = [
# ----> 4     go.Mesh3d(
#       5         x = [0, 0, 1, 1, 0, 0, 1, 1],
#       6         y = [0, 1, 1, 0, 0, 1, 1, 0],
#
# NameError: name 'go' is not defined

# %%
plt.plot(dataDem[5],dataDem[6],'.b', dataRep[5], dataRep[6],'.r')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.title('ALL')
plt.show()
